# %% [markdown]
# <a href="https://colab.research.google.com/github/suresh46-ops/suresh/blob/main/9th_day_File_Handling_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open ('suresh.txt', 'w') as f:
  f.write('hello suresh from combined cell')

# %%
with open ('suresh.txt', 'r') as f:
  print(f.read())
# Out:
# hello suresh from combined cell

# %%
import csv
with open('mycsv.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(['col1', 'col2'])
    writer.writerow(['data1', 'data2'])

# %%
import pandas as suresh

# %%
import pandas as suresh
suresh.read_csv('mycsv.csv')
# Out:
#     col1   col2
# 0  data1  data2
